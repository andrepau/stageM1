# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
 
def ricker(tp,ts=0.25, a=1, min=0.001, max=2, dt=0.001):
    """Trace la fonction de Ricker en temps et en frequences. 
    Correspond à la fonction n°6 dans EFISPEC3D (http://efispec.free.fr/docs/html/classmod__source__function.html#a848915deaa3b241fe68fc8671e414962)
    
    ricker(tp,ts,a,min,max,dt) 
    
    tp = 1/frequence fondamentale
    ts= décalage en temps (time shift) par défaut =0.25s
    a= amplitude facteur, par défaut = 1
    min = temps min, par défaut =0.001s
    max = temps max, par defaut =2s
     """
    t = np.arange(min, max, dt)
    y = 2.0*a*((np.pi**2)*((1/(tp**2))*((t-ts)**2))-0.5)* np.exp(-(np.pi**2)*(1/(tp**2))*((t-ts)**2))
    f=1/t
    f1=1/tp
    A=((f/f1)**2)*(1/(np.exp((f/f1)**2)))
    plt.figure(figsize=(15,5))
    plt.subplot(121)
    plt.plot(t,y)
    
    tsimu=max
    xt=np.linspace(tsimu,tsimu,50)
    yt=np.linspace(-1.5,1.5,50)
    plt.plot(xt,yt)
    
    plt.title('Ricker domaine temporel')
    plt.xlabel('temps (s)')
    plt.ylim(-1.5,1.5)
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    plt.subplot(122)
    plt.plot(f,A)
    plt.xlim(0,100)
    plt.title('Ricker domaine frequentiel')
    plt.xlabel('frequence (Hz)')
    plt.ylabel('Amplitude')
    plt.grid(True)
    
    print('f1=', f1)
    #return t, y, f, f1, A

# %%
tp = 1/20
ricker(tp)
# Out:
# C:\Users\Pauli\anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in exp
# f1= 20.0

# %%
tp = 0.2
ricker(tp)
# Out:
# C:\Users\Pauli\anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in exp
# f1= 5.0

# %%
help(ricker)
# Out:
# Help on function ricker in module __main__:
#
# ricker(tp, ts=0.25, a=1, min=0.001, max=2, dt=0.001)
#     Trace la fonction de Ricker en temps et en frequences.
#     Correspond à la fonction n°6 dans EFISPEC3D (http://efispec.free.fr/docs/html/classmod__source__function.html#a848915deaa3b241fe68fc8671e414962)
#
#     ricker(tp,ts,a,min,max,dt)
#
#     tp = 1/frequence fondamentale
#     ts= décalage en temps (time shift) par défaut =0.25s
#     a= amplitude facteur, par défaut = 1
#     min = temps min, par défaut =0.001s
#     max = temps max, par defaut =2s

# %%
tp=1/20
ts=0.25 
a=1 
dmin=0.001 
dmax=2
dt=0.001

# %%
t = np.arange(dmin, dmax, dt)
y = 2.0*a*((np.pi**2)*((1/(tp**2))*((t-ts)**2))-0.5)* np.exp(-(np.pi**2)*(1/(tp**2))*((t-ts)**2))
f=1/t
f1=1/tp
plt.figure(figsize=(15,5))
   
plt.plot(t,y)
    
plt.title('Ricker domaine temporel')
plt.xlabel('temps (s)')
plt.ylim(-1.5,1.5)
plt.ylabel('Amplitude')
plt.grid(True)

# %%
Y=np.fft.fft(y)
f=1/t

plt.figure(figsize=(15,5))
   
plt.plot(f/30,abs(Y))
    
plt.title('Ricker domaine freq')
plt.xlabel('Hz)')
plt.xlim(0.2,40)
plt.ylabel('Amplitude')
plt.grid(True)
