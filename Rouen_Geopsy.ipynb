# %% [markdown]
# **Notebook sur les courbes de dispersions Geopsy sur les données MASW Rouen**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import fonction_stage as st

# %% [markdown]
# 19 Septement P0 001 (source à -5.5)

# %%
st.plot_dispcurve_lim('01_P0_19sept',plotvmax=400)
# Out:
# wlmax1 (pour wl max < L) = 24 m
# wlmax2 (pour wl max < 2*x1) = 12 m
# wlmax3 (wl max < 0.4L) = 9.600000000000001 m
# wlmax4 (edf : wl< 0.5L)= 12.0 m
# wlmin (pour aliasing quand wl < 2*dx)= 2 m
# wlmin2 (edf wl < dx)= 1 m
